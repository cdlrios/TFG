# %%
import pandas as pd
import statsmodels.api as sm

# %%
df = pd.read_csv("data_metro.csv",delimiter=";")

# %%
df.drop(columns=['Código_es', 'nombre_estación'], inplace=True)

# %%
df.info()      # para ver tipos de datos y nulos
df.describe()  # resumen estadístico de las variables numéricas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   demanda            184 non-null    int64
#  1   Num_linea          184 non-null    int64
#  2   Cercanias          184 non-null    int64
#  3   Bus_inter          184 non-null    int64
#  4   Renfe_LR           184 non-null    int64
#  5   Oficina_TPP        184 non-null    int64
#  6   Eventodromo_500    184 non-null    int64
#  7   Aparcadisu_gratis  184 non-null    int64
#  8   Aparcadisu_pago    184 non-null    int64
#  9   hog_tot            184 non-null    int64
#  10  pob_tot            184 non-null    int64
#  11  edad_media         184 non-null    object
#  12  person_hogar       184 non-null    object
#  13  renper_pon         184 non-null    object
#  14  renhog_pon         184 non-null    object
#  15  dens_pond          184 non-null    object
# ...

# %%
# Matriz de correlación de todas las variables numéricas
correlacion = df.corr(numeric_only=True)

# Ver las primeras filas (opcional)
correlacion.head()
# Out:
#             demanda  Num_linea  Cercanias  Bus_inter  Renfe_LR  Oficina_TPP  \
# demanda    1.000000   0.677780   0.376792   0.541901  0.302549     0.559543
# Num_linea  0.677780   1.000000   0.165128   0.303870  0.149457     0.304670
# Cercanias  0.376792   0.165128   1.000000   0.274008  0.679229     0.260250
# Bus_inter  0.541901   0.303870   0.274008   1.000000  0.506365     0.272051
# Renfe_LR   0.302549   0.149457   0.679229   0.506365  1.000000    -0.029196
#
#            Eventodromo_500  Aparcadisu_gratis  Aparcadisu_pago   hog_tot  \
# demanda          -0.015385          -0.019976         0.210894  0.016880
# Num_linea        -0.032663           0.029253         0.137504  0.006931
# Cercanias        -0.092526           0.062614         0.442821  0.135631
# Bus_inter        -0.059989          -0.027933        -0.033237 -0.022315
# Renfe_LR         -0.046210          -0.021517         0.198725 -0.029221
#
#             pob_tot
# demanda   -0.168679
# Num_linea -0.216191
# ...

# %%
correlacion['demanda'].sort_values(ascending=False)
# Out:
# demanda              1.000000
# Num_linea            0.677780
# Oficina_TPP          0.559543
# Bus_inter            0.541901
# Cercanias            0.376792
# Renfe_LR             0.302549
# Aparcadisu_pago      0.210894
# hog_tot              0.016880
# Eventodromo_500     -0.015385
# Aparcadisu_gratis   -0.019976
# pob_tot             -0.168679
# Name: demanda, dtype: float64
